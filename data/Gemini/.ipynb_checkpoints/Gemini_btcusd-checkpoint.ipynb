# %%
import websocket
import json
import pandas as pd
try:
    import thread
except ImportError:
    import _thread as thread
import time

coin = "btcusd" #Set you coin
init = 1
header = {"type":[],"eventId":[],"timestamp":[],"timestampms":[],"socket_sequence":[],"events":[]}#"delta":[],"price":[],"reason":[],"remaining":[],"side":[],"events-type":[]}
header = pd.DataFrame(header)

def on_message(ws, message):
    result = json.loads(message)
    lst = pd.DataFrame.from_dict(result)
    global init, coin
    if (init == 1):
        #file path, one for initial data, one for transaction records
        #the folder needs to be created before the program
        lst.to_csv('1-22/'+coin+'_init.csv', header=True, index=False)
        header.to_csv('1-22/'+coin+'.csv', header=True,index=False)
        init = 0
    else:
        #events = pd.DataFrame.from_dict(result['events']) 
        #lst = lst.drop('events',axis=1)
        #lst = pd.concat([lst,events],axis=1)
        lst.to_csv('1-22/'+coin+'.csv', mode= 'a', header=False, index=False)
def on_error(ws, error):
    print(error)

def on_close(ws):
    print("### closed ###")

if __name__ == "__main__":
    websocket.enableTrace(True)
    #url here, add any other options according to API document
    ws = websocket.WebSocketApp("wss://api.gemini.com/v1/marketdata/"+coin+"?bids=true&offers=true&trades=true",
                              on_message = on_message,
                              on_error = on_error,
                              on_close = on_close)
    ws.run_forever(ping_interval=60)
# Out:
# --- request header ---
# GET /v1/marketdata/btcusd?bids=true&offers=true&trades=true HTTP/1.1
# Upgrade: websocket
# Connection: Upgrade
# Host: api.gemini.com
# Origin: http://api.gemini.com
# Sec-WebSocket-Key: WrPx6iQZU+83/ll9TAub0Q==
# Sec-WebSocket-Version: 13
#
#
# -----------------------
# --- response header ---
# HTTP/1.1 101 Switching Protocols
# Date: Tue, 22 Jan 2019 19:44:02 GMT
# Connection: upgrade
# Server: nginx
# Upgrade: websocket
# Sec-WebSocket-Accept: f2eulL3bBd8NLQjjaDb/VHqffr4=
# -----------------------
# send: b'\x89\x80oT|\xf1'
# send: b'\x89\x80U\xf9X\xd1'
# send: b'\x89\x80\xedG\x8cy'
# send: b'\x89\x80\x138\x13X'
# send: b'\x89\x80\xcc\n\xd1\xcb'
# send: b'\x89\x80\xe1\xcc\x08\xd5'
# send: b'\x89\x80)!\x14~'
# send: b'\x89\x80\x89\x19\xf5\x88'
# send: b'\x89\x80X6G;'
# send: b'\x89\x80=\x97\x0e\x06'
# send: b'\x89\x80\xbeo)\x1f'
# send: b'\x89\x80\xbevi\x91'
# send: b'\x89\x80\x8f,\x04\x91'
# send: b'\x89\x80\xdfW\xfd\xb9'
# send: b'\x89\x80\x0c\xa2\x9c\x13'
# send: b'\x89\x80\xfb\xadw\x98'
# send: b'\x89\x80\x12F\xc8\x94'
# send: b'\x89\x80\xcbL\xd1\x9d'
# send: b'\x89\x80\x13\xbao\xc5'
# send: b'\x89\x80;1<\xe2'
# send: b'\x89\x808f\x0fS'
# send: b'\x89\x80\xc7=\x8c{'
# send: b'\x89\x80\xb6~c\x84'
# send: b'\x89\x80!\x87\xb9e'
# send: b'\x89\x80D\x8cu\xdb'
# send: b'\x89\x80-\x1e2\xec'
# send: b'\x89\x80a_4\xea'
# send: b'\x89\x80k\x97\xf6u'
# send: b'\x89\x80k\xcd\xe2\x95'
# send: b'\x89\x80\x18j\xdf\x7f'
# send: b'\x89\x80\xcf\xda\x80\x82'
# send: b'\x89\x80o\xa0\xf2<'
# send: b'\x89\x80R.Q\x1c'
# send: b'\x89\x80x\x91\xb8S'
# send: b'\x89\x80\x91\xc8\xf8\xdd'
# send: b'\x89\x80\xfa\xf6\xc8-'
# send: b'\x89\x80\xac\x04(\xd6'
# send: b'\x89\x80"\xafS\x91'
# send: b'\x89\x80y\xf5\xd3\xf1'
# send: b'\x89\x80\xa2\xe6\xa12'
# send: b'\x89\x80y\x1aS8'
# send: b'\x89\x80\xe2\xe2\x07\x9e'
# send: b'\x89\x80\xcap\xce\xff'
# send: b'\x89\x80\xe1Q\x93k'
# send: b'\x89\x80bo`]'
# send: b'\x89\x80n h\x13'
# send: b'\x89\x80\xcb\xe8HM'
# send: b'\x89\x80~\xf7n\xd2'
# send: b'\x89\x80\xc0G\xfe\x92'
# send: b'\x89\x80\x96L\xe28'
# send: b'\x89\x80\x03w\xaa\x1a'
# send: b'\x89\x80&{\x99\n'
# send: b'\x89\x80rJM\xad'
# send: b'\x89\x80P\xa57\xa2'
# send: b'\x89\x80\xea7\x9fe'
# send: b'\x89\x80\xbd\xae\xcc\xfc'
# send: b'\x89\x80\x16\xee\x15\x1f'
# send: b'\x89\x80\xfe\xb6\x96U'
# send: b'\x89\x80\x8f-5\xbd'
# send: b'\x89\x80\xe5\x15d\x05'
# send: b'\x89\x80\xfc\xe7J>'
# send: b'\x89\x80\xeap\xaaG'
# send: b'\x89\x80\xa5\x06\x8f<'
# send: b'\x89\x80\xdc\x19\xb6\xef'
# send: b'\x89\x805W\x90\xec'
# send: b'\x89\x80\xf9x~\xda'
# send: b'\x89\x80w\x1c\xcb\x1d'
# send: b'\x89\x80\xa2\x80#\x1a'
# send: b'\x89\x80W\xeb\x86\x0e'
# send: b'\x89\x80\xc4\xbb\x909'
# send: b'\x89\x80\xea\xc5\xd0\xc4'
# send: b'\x89\x80\x1f\xaf\xd0{'
# send: b'\x89\x80\xae\xb6V\xf8'
# send: b'\x89\x80\xd6v\x96\xf4'
# send: b'\x89\x80\xa4\x02\xdd\xa8'
# send: b'\x89\x80\xb0\xf5\xc7\xd4'
# send: b'\x89\x80\xb81g\x9d'
# send: b'\x89\x80\xcd\xea\x86\xce'
# send: b'\x89\x80cy\xb9\xb3'
# send: b'\x89\x80O/\xb0^'
# send: b'\x89\x80L\x0eIs'
# send: b'\x89\x80\xa8\xcd\xaa;'
# send: b'\x89\x80m\xef\xe6g'
# send: b'\x89\x80\x9e\x08f\x9c'
# send: b'\x89\x80\x14\xbb\x0ej'
# send: b'\x89\x80\xd5%\x88\xcc'
# send: b'\x89\x80\x9e$\xca\xb6'
# send: b'\x89\x80c*X\xc9'
# send: b'\x89\x80L\x88g\xef'
# send: b'\x89\x80#W2\\'
# send: b'\x89\x80+k\xb4H'
# send: b'\x89\x80\xa6\xe0<\x8e'
# send: b'\x89\x80\x8a\xf3\xe6x'
# send: b'\x89\x80$\xf5\x84i'
# send: b'\x89\x80|\x88\xf4\xab'
# send: b'\x89\x80\x96\xfd\xb1\xc8'
# send: b'\x89\x80\x93\xda\xb0,'
# send: b'\x89\x80\xe2\xe9\x80\xcb'
# send: b'\x89\x80$\xa6(\x03'
# send: b'\x89\x80pK\xf5\xdf'
# send: b'\x89\x80\xa2\\\x16\xa6'
# send: b'\x89\x80\x8b\x94\xa5\xfc'
# send: b'\x89\x80\x9a9\xce\x91'
# send: b'\x89\x80\xd8\xe8\xf7\xfd'
# send: b'\x89\x80"C\x148'
# send: b'\x89\x80\xdb\xd1\xad\xb3'
# send: b'\x89\x80\x97\xb7\xb1X'
# send: b'\x89\x80\x98\x08\x8a\x0c'
# send: b'\x89\x80\x88g\x18\xa3'
# send: b'\x89\x80=\xaa\x15 '
# send: b'\x89\x80\xfa\xae\x9c\xd0'
# send: b'\x89\x80-!i|'
# send: b'\x89\x80,"\x05\xca'
# send: b'\x89\x80\x15\xc8{\xe6'
# send: b'\x89\x80d\xb3\x1bb'
# send: b'\x89\x80\xea\x95\x9d\xea'
# send: b'\x89\x80N\xaaH\xb4'
# send: b'\x89\x80\x9b\xfe{\xe2'
# send: b'\x89\x80\x14c\xb0['
# send: b'\x89\x80\x8b\x96\x8c\x0f'
# send: b'\x89\x80+\x8c\x1d\xa9'
# send: b'\x89\x80\xc5\xdd\xd6\x1a'
# send: b'\x89\x80R}\xfc('
# send: b'\x89\x80_\xc1w8'
# send: b'\x89\x80\x81@l\xc2'
# send: b'\x89\x80\xb6e\x01E'
# send: b'\x89\x807\xb1\xd0\xd7'
# send: b'\x89\x80\x16T%R'
# send: b'\x89\x80\xb5\xd6\xeaG'
# send: b'\x89\x80\xea\x10\x1ap'
# send: b'\x89\x80\x96F\xeb\xbb'
# send: b'\x89\x80w\xc7\t\x19'
# send: b'\x89\x805\xe2\x9e\xd2'
# send: b'\x89\x80t\x804\x90'
# send: b'\x89\x80\x84zS\xe4'
# send: b'\x89\x80\xf4n\x993'
# send: b'\x89\x80*E\xb28'
# send: b'\x89\x80\xbc\xcc\xfb\x9f'
# send: b'\x89\x80\xd6#\xec\xdc'
# send: b'\x89\x80K\xf0\xa2\xd0'
# send: b'\x89\x80\x80#\xa4I'
# send: b'\x89\x80\x02Uo\xeb'
# send: b'\x89\x80\x94\x93\xc8M'
# send: b'\x89\x80d_\x9c\xc5'
# send: b'\x89\x80\xa3T*\xd9'
# send: b'\x89\x80xW;\x00'
# send: b'\x89\x80z<\xc3\x8b'
# send: b'\x89\x80\xae\x15\x8a\x00'
# send: b'\x89\x80\xfa\xf2\xe1\x7f'
# send: b'\x89\x80\xafI\xd7\x10'
# send: b'\x89\x80\xd8\xda\xcd\xd8'
# send: b"\x89\x80'\x9dC\x1e"
# send: b'\x89\x80\xf2\x8ef\xac'
# send: b'\x89\x80a\x06N\xc7'
# send: b'\x89\x80\x8c/\xf2\xdb'
# send: b'\x89\x80fyN"'
# send: b'\x89\x80\x88\x92\xf5\x1d'
# send: b'\x89\x80\x07\xc7C\x01'
# send: b'\x89\x809\x7f\xf5\x0e'
# send: b'\x88\x828L\xf9\xff;\xa4'
# [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# ### closed ###
